# %% [markdown]
# # Analise de data/raw/solicitacoes_internas.csv

# %%
import os
import pandas as pd

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('.')))))
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR = os.path.join(DATA_DIR, 'raw')

# %%
df = pd.read_csv(os.path.join(RAW_DIR, 'solicitacoes_internas.csv'))
df.shape
# Out:
# (100, 8)

# %%
df.head()
# Out:
#    id_solicitacao data_solicitacao        solicitante    departamento  \
# 0           13001       2026-01-05      Natalia Gomes              TI
# 1           13002       2026-01-07     Daniel Almeida       Comercial
# 2           13003       2026-01-09    Beatriz Martins  Administrativo
# 3           13004       2026-01-12  Gabriel Rodrigues              TI
# 4           13005       2026-01-14        Amanda Melo       Comercial
#
#   tipo_solicitacao prioridade     status  prazo_dias
# 0           Compra       Alta  Cancelada           3
# 1               RH      Baixa  Concluida          10
# 2       Manutenção      Baixa  Concluida           7
# 3           Compra       Alta  Concluida          10
# 4           Compra       Alta  Concluida           5

# %%
df.tail()
# Out:
#     id_solicitacao data_solicitacao      solicitante      departamento  \
# 95           13096       2026-08-21    Natalia Gomes         Comercial
# 96           13097       2026-08-23  Leonardo Vieira         Comercial
# 97           13098       2026-08-26     Felipe Cunha  Recursos Humanos
# 98           13099       2026-08-28    Matheus Pires        Financeiro
# 99           13100       2026-08-31    Gisele Moraes           Compras
#
#    tipo_solicitacao prioridade        status  prazo_dias
# 95           Compra      Media     Cancelada           3
# 96        Documento      Media     Concluida           7
# 97       Financeiro       Alta     Cancelada          10
# 98        Documento      Media     Concluida           2
# 99       Manutenção      Media  Em andamento          10

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_solicitacao    100 non-null    int64
#  1   data_solicitacao  100 non-null    str
#  2   solicitante       100 non-null    str
#  3   departamento      100 non-null    str
#  4   tipo_solicitacao  100 non-null    str
#  5   prioridade        100 non-null    str
#  6   status            100 non-null    str
#  7   prazo_dias        100 non-null    int64
# dtypes: int64(2), str(6)
# memory usage: 6.4 KB

# %%
df.duplicated().sum()
