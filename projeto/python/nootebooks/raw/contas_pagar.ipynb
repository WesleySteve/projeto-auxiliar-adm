# %% [markdown]
# # Analise de data/raw/contas_pagar.csv

# %%
import os
import pandas as pd

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('.')))))
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR = os.path.join(DATA_DIR, 'raw')

# %%
df = pd.read_csv(os.path.join(RAW_DIR, 'contas_pagar.csv'))
df.shape
# Out:
# (180, 9)

# %%
df.head()
# Out:
#    id_conta data_emissao data_vencimento  id_fornecedor            descricao  \
# 0      5001   2026-01-02      2026-01-09           2010  Compra de alimentos
# 1      5002   2026-01-03      2026-02-02           2018     Conta de energia
# 2      5003   2026-01-04      2026-01-19           2013     Serviço contábil
# 3      5004   2026-01-05      2026-02-19           2005   Serviço de limpeza
# 4      5005   2026-01-07      2026-01-22           2001  Serviço de internet
#
#         categoria    valor     status      responsavel
# 0        Serviços  1600.35       Pago  Vinicius Castro
# 1  Infraestrutura  4221.02       Pago    Karen Freitas
# 2  Infraestrutura  1265.06  Aprovacao      Igor Mendes
# 3      Tecnologia  1292.94  Aprovacao   Wesley Martins
# 4  Administrativo  3860.91   Pendente  Rodrigo Tavares
