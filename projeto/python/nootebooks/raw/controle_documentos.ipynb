# %% [markdown]
# # Analise de data/raw/controle_documentos.csv

# %%
import os
import pandas as pd

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('.')))))
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR = os.path.join(DATA_DIR, 'raw')

# %%
df = pd.read_csv(os.path.join(RAW_DIR, 'controle_documentos.csv'))
df.shape
# Out:
# (120, 7)

# %%
df.head()
# Out:
#    id_documento tipo_documento              descricao data_recebimento  \
# 0         11001         Boleto       Processo interno       2026-01-03
# 1         11002    Nota Fiscal       Processo interno       2026-01-05
# 2         11003         Boleto  Compra administrativa       2026-01-07
# 3         11004    Nota Fiscal      Documento cliente       2026-01-09
# 4         11005         Boleto      Documento cliente       2026-01-11
#
#               responsavel     status local_arquivo
# 0  Camila Oliveira Santos  Arquivado       Compras
# 1           Gisele Moraes   Pendente    Financeiro
# 2         Diego Fernandes   Pendente            RH
# 3           Giovana Lopes  Arquivado       Compras
# 4          Thiago Rezende  Conferido       Digital

# %%
df.tail()
# Out:
#      id_documento    tipo_documento              descricao data_recebimento  \
# 115         11116  Pedido de Compra    Prestação de contas       2026-08-22
# 116         11117          Contrato      Documento cliente       2026-08-24
# 117         11118  Pedido de Compra       Processo interno       2026-08-26
# 118         11119            Boleto  Compra administrativa       2026-08-28
# 119         11120       Nota Fiscal   Documento fornecedor       2026-08-31
#
#            responsavel     status   local_arquivo
# 115  Patricia Teixeira   Pendente      Financeiro
# 116    Leonardo Vieira   Pendente      Financeiro
# 117     Sandra Batista   Pendente  Administrativo
# 118       Yasmin Alves  Conferido      Financeiro
# 119     Fernanda Souza  Conferido         Digital

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_documento      120 non-null    int64
#  1   tipo_documento    120 non-null    str
#  2   descricao         120 non-null    str
#  3   data_recebimento  120 non-null    str
#  4   responsavel       120 non-null    str
#  5   status            120 non-null    str
#  6   local_arquivo     120 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 6.7 KB
