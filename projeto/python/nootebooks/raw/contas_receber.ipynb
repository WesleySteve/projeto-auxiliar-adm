# %% [markdown]
# # Analise de data/raw/contas_receber.csv

# %%
import os
import pandas as pd

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('.')))))
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR = os.path.join(DATA_DIR, 'raw')

# %%
df = pd.read_csv(os.path.join(RAW_DIR, 'contas_receber.csv'))
df.shape
# Out:
# (140, 8)

# %%
df.head()
# Out:
#    id_recebimento           cliente data_emissao data_vencimento  \
# 0            7001  Cliente Nova Era   2026-01-05      2026-02-04
# 1            7002     Cliente Delta   2026-01-06      2026-02-05
# 2            7003  Cliente Nova Era   2026-01-08      2026-02-07
# 3            7004   Comercial Oeste   2026-01-10      2026-01-17
# 4            7005    Grupo Prudente   2026-01-11      2026-01-18
#
#               descricao     valor     status forma_pagamento
# 0    Serviço recorrente   2023.18   Recebido   Transferência
# 1           Consultoria  14775.60   Pendente          Boleto
# 2  Prestação de serviço   7036.42   Recebido   Transferência
# 3  Prestação de serviço   9713.74  Em atraso          Boleto
# 4           Consultoria   2465.33   Pendente          Boleto

# %%
df.tail()
# Out:
#      id_recebimento           cliente data_emissao data_vencimento  \
# 135            7136   Comercial Oeste   2026-08-18      2026-09-02
# 136            7137     Cliente Delta   2026-08-19      2026-10-03
# 137            7138    Grupo Prudente   2026-08-21      2026-08-28
# 138            7139  Cliente Nova Era   2026-08-23      2026-09-13
# 139            7140   Comercial Oeste   2026-08-25      2026-09-09
#
#                 descricao     valor     status forma_pagamento
# 135    Serviço recorrente  17253.15   Recebido   Transferência
# 136  Prestação de serviço  10528.23   Recebido             PIX
# 137           Consultoria  16822.79   Recebido          Boleto
# 138           Consultoria  10565.36   Recebido             PIX
# 139           Consultoria   8888.70  Em atraso          Cartão

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_recebimento   140 non-null    int64
#  1   cliente          140 non-null    str
#  2   data_emissao     140 non-null    str
#  3   data_vencimento  140 non-null    str
#  4   descricao        140 non-null    str
#  5   valor            140 non-null    float64
#  6   status           140 non-null    str
#  7   forma_pagamento  140 non-null    str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 8.9 KB
