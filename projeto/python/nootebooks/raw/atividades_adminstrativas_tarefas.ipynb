# %% [markdown]
# # Analise de data/raw/atividades_administrativas.csv

# %%
import os
import pandas as pd

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('.')))))
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR = os.path.join(DATA_DIR, 'raw')

# %%
df = pd.read_csv(os.path.join(RAW_DIR, 'atividades_administrativas.csv'))
df.shape
# Out:
# (90, 7)

# %%
df.head()
# Out:
#    id_atividade        data      responsavel            atividade prioridade  \
# 0         15001  2026-07-01  Leonardo Vieira      Gerar relatório       Alta
# 1         15002  2026-07-01  Rodrigo Tavares   Organizar arquivos       Alta
# 2         15003  2026-07-02  Helena Ferreira   Atualizar cadastro       Alta
# 3         15004  2026-07-03    Raquel Mendes      Gerar relatório      Media
# 4         15005  2026-07-03  Helena Ferreira  Conferir documentos      Baixa
#
#       status  tempo_estimado_min
# 0  Concluida                  90
# 1   Pendente                  30
# 2  Concluida                  60
# 3  Concluida                  45
# 4   Pendente                  30

# %%
df.tail()
# Out:
#     id_atividade        data     responsavel                    atividade  \
# 85         15086  2026-08-28     Hugo Barros          Conferir pagamentos
# 86         15087  2026-08-28   Raquel Mendes           Atualizar planilha
# 87         15088  2026-08-29  Renata Moreira  Atender solicitação interna
# 88         15089  2026-08-30  Thiago Rezende          Conferir pagamentos
# 89         15090  2026-08-31   Tatiane Rocha              Gerar relatório
#
#    prioridade        status  tempo_estimado_min
# 85      Baixa     Concluida                 120
# 86       Alta  Em andamento                  30
# 87      Baixa     Concluida                  15
# 88      Baixa     Concluida                 120
# 89      Media     Concluida                  30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_atividade        90 non-null     int64
#  1   data                90 non-null     str
#  2   responsavel         90 non-null     str
#  3   atividade           90 non-null     str
#  4   prioridade          90 non-null     str
#  5   status              90 non-null     str
#  6   tempo_estimado_min  90 non-null     int64
# dtypes: int64(2), str(5)
# memory usage: 5.1 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
