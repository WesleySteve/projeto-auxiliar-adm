# %% [markdown]
# # Analise de data/raw/fornecedores.csv

# %%
import os
import pandas as pd

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('.')))))
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR = os.path.join(DATA_DIR, 'raw')

# %%
df = pd.read_csv(os.path.join(RAW_DIR, 'fornecedores.csv'))
df.shape
# Out:
# (20, 6)

# %%
df.head()
# Out:
#    id_fornecedor            fornecedor            categoria           cidade  \
# 0           2001     Papelaria Central           Transporte  Álvares Machado
# 1           2002      Office Solutions              Limpeza  Santo Anastácio
# 2           2003         Limpeza Ideal              Limpeza  Álvares Machado
# 3           2004        Tecno Sistemas  Material Escritório    Regente Feijó
# 4           2005  Transportes Paulista          Alimentação  Álvares Machado
#
#    prazo_pagamento_dias   status
# 0                    28    Ativo
# 1                     7    Ativo
# 2                     7    Ativo
# 3                    15  Inativo
# 4                    45    Ativo

# %%
df.tail()
# Out:
#     id_fornecedor            fornecedor    categoria               cidade  \
# 15           2016  Correios Empresarial  Alimentação      Álvares Machado
# 16           2017        RH Consultoria     Serviços        Regente Feijó
# 17           2018    Marketing Criativo      Limpeza      Santo Anastácio
# 18           2019        Software Cloud   Transporte  Presidente Prudente
# 19           2020   Alimentos Bom Sabor   Transporte      Álvares Machado
#
#     prazo_pagamento_dias   status
# 15                    45    Ativo
# 16                    28  Inativo
# 17                    30    Ativo
# 18                    30    Ativo
# 19                    21    Ativo

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_fornecedor         20 non-null     int64
#  1   fornecedor            20 non-null     str
#  2   categoria             20 non-null     str
#  3   cidade                20 non-null     str
#  4   prazo_pagamento_dias  20 non-null     int64
#  5   status                20 non-null     str
# dtypes: int64(2), str(4)
# memory usage: 1.1 KB
